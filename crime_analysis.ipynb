# %% [markdown]
# <u><h1 style="background-color:#b3e6ff; color:#3d0066;font-size:40px;">Coursework 2 - Practical Report Summary</h1></u>

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:30px;">1. Import Libraries and Dataset</h1>

# %%
#importing all the required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the dataset and storing it in a dataframe
df = pd.read_csv('D:\MSc Data Science\CI7340 - Applied Data Programming\Coursework\Assessment 1\Crime.csv',low_memory=False)

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:30px;"> 2. Dataset Summary</h1>

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;">2.1 Dataset overview</h1>

# %%
df.head() #printing 1st 10 rows of the dataset
# Out:
#    Incident ID Offence Code  CR Number    Dispatch Date / Time NIBRS Code  \
# 0    201219928         1204  180063894  12/21/2018 09:13:13 PM        120
# 1    201301798         5016  200035833  09/13/2020 12:26:58 AM        90Z
# 2    201221577         5404  190000342  01/03/2019 02:48:47 AM        90D
# 3    201221577         9053  190000342  01/03/2019 02:48:47 AM        90Z
# 4    201294935         2303  200027681  07/16/2020 05:29:50 PM        23C
#
#    Victims             Crime Name1                  Crime Name2  \
# 0        1  Crime Against Property                      Robbery
# 1        1   Crime Against Society           All Other Offenses
# 2        1   Crime Against Society  Driving Under the Influence
# 3        1                   Other           All Other Offenses
# 4        1  Crime Against Property                  Shoplifting
#
#                                   Crime Name3 Police District Name  ...  \
# ...

# %%
df.tail() #printing last 10 rows of the dataset
# Out:
#         Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 315896    201395447         1399  220043955  10/08/2022 01:03:21 AM
# 315897    201395456         2303  220043851  10/07/2022 02:16:41 PM
# 315898    201395462         2303  220043819  10/07/2022 12:04:02 PM
# 315899    201395475         1399  220043976  10/08/2022 09:03:17 AM
# 315900    201395485         2303  220043987  10/08/2022 11:07:28 AM
#
#        NIBRS Code  Victims             Crime Name1     Crime Name2  \
# 315896        13B        1    Crime Against Person  Simple Assault
# 315897        23C        1  Crime Against Property     Shoplifting
# 315898        23C        1  Crime Against Property     Shoplifting
# 315899        13B        1    Crime Against Person  Simple Assault
# 315900        23C        1  Crime Against Property     Shoplifting
#
#                   Crime Name3 Police District Name  ... Street Prefix  \
# 315896   ASSAULT - 2ND DEGREE            ROCKVILLE  ...           NaN
# ...

# %%
df.info() #printing the no of records in each attribute and their corressponding datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315901 entries, 0 to 315900
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Incident ID             315901 non-null  int64
#  1   Offence Code            315901 non-null  object
#  2   CR Number               315901 non-null  int64
#  3   Dispatch Date / Time    266755 non-null  object
#  4   NIBRS Code              315901 non-null  object
#  5   Victims                 315901 non-null  int64
#  6   Crime Name1             315617 non-null  object
#  7   Crime Name2             315617 non-null  object
#  8   Crime Name3             315617 non-null  object
#  9   Police District Name    315808 non-null  object
#  10  Block Address           289053 non-null  object
#  11  City                    314626 non-null  object
#  12  State                   315901 non-null  object
#  13  Zip Code                312720 non-null  float64
# ...

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;">2.2 Dimension of Dataset </h1>

# %%
df.shape #finding the no of rows and columns of the dataframe
# Out:
# (315901, 30)

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;">2.3 Column names </h1>

# %%
df.columns
# Out:
# Index(['Incident ID', 'Offence Code', 'CR Number', 'Dispatch Date / Time',
#        'NIBRS Code', 'Victims', 'Crime Name1', 'Crime Name2', 'Crime Name3',
#        'Police District Name', 'Block Address', 'City', 'State', 'Zip Code',
#        'Agency', 'Place', 'Sector', 'Beat', 'PRA', 'Address Number',
#        'Street Prefix', 'Street Name', 'Street Suffix', 'Street Type',
#        'Start_Date_Time', 'End_Date_Time', 'Latitude', 'Longitude',
#        'Police District Number', 'Location'],
#       dtype='object')

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;">2.4 Datatypes of each attribute</h1>

# %%
pd.DataFrame(df.dtypes, columns=['Datatype']).rename_axis('Columns')
# Out:
#                        Datatype
# Columns
# Incident ID               int64
# Offence Code             object
# CR Number                 int64
# Dispatch Date / Time     object
# NIBRS Code               object
# Victims                   int64
# Crime Name1              object
# Crime Name2              object
# Crime Name3              object
# Police District Name     object
# Block Address            object
# City                     object
# State                    object
# Zip Code                float64
# Agency                   object
# Place                    object
# Sector                   object
# Beat                     object
# PRA                      object
# Address Number          float64
# Street Prefix            object
# Street Name              object
# Street Suffix            object
# Street Type              object
# Start_Date_Time          object
# End_Date_Time            object
# Latitude                float64
# Longitude               float64
# ...

# %%
df.describe()
# Out:
#         Incident ID     CR Number        Victims       Zip Code  \
# count  3.159010e+05  3.159010e+05  315901.000000  312720.000000
# mean   2.012417e+08  1.708484e+08       1.022782   20876.526465
# std    8.905245e+04  6.176686e+07       0.193279     167.536899
# min    2.010871e+08  1.001107e+07       1.000000       6.000000
# 25%    2.011648e+08  1.705460e+08       1.000000   20853.000000
# 50%    2.012408e+08  1.900242e+08       1.000000   20878.000000
# 75%    2.013180e+08  2.100034e+08       1.000000   20904.000000
# max    2.013967e+08  3.300378e+08      22.000000   29882.000000
#
#        Address Number       Latitude      Longitude
# count    2.891510e+05  315901.000000  315901.000000
# mean     8.406307e+03      38.014859     -75.010190
# std      1.617291e+04       6.368865      12.565266
# min      1.000000e+00       0.000000     -77.516753
# 25%      1.600000e+03      39.019801     -77.197020
# 50%      8.100000e+03      39.072286     -77.098956
# ...

# %%
df.hist(figsize=(20, 30))
# Out:
# array([[<AxesSubplot:title={'center':'Incident ID'}>,
#         <AxesSubplot:title={'center':'CR Number'}>,
#         <AxesSubplot:title={'center':'Victims'}>],
#        [<AxesSubplot:title={'center':'Zip Code'}>,
#         <AxesSubplot:title={'center':'Address Number'}>,
#         <AxesSubplot:title={'center':'Latitude'}>],
#        [<AxesSubplot:title={'center':'Longitude'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# #### Date and Time attributes are not in the correct date-time formats

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:30px;"> 3.  Analysing Quality of Data</h1>

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;">3.1 Missing data count </h1>

# %%
df.isnull().sum()
# Out:
# Incident ID                    0
# Offence Code                   0
# CR Number                      0
# Dispatch Date / Time       49146
# NIBRS Code                     0
# Victims                        0
# Crime Name1                  284
# Crime Name2                  284
# Crime Name3                  284
# Police District Name          93
# Block Address              26848
# City                        1275
# State                          0
# Zip Code                    3181
# Agency                         0
# Place                          0
# Sector                      1793
# Beat                        1793
# PRA                          245
# Address Number             26750
# Street Prefix             301749
# Street Name                    1
# Street Suffix             310447
# Street Type                  340
# Start_Date_Time                0
# End_Date_Time             167070
# Latitude                       0
# Longitude                      0
# ...

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;">3.2 Missing data in percentage </h1>

# %%
print(((df.isnull().sum()).sort_values(ascending=False) / df.shape[0])*100)
# Out:
# Street Suffix             98.273510
# Street Prefix             95.520115
# End_Date_Time             52.886822
# Dispatch Date / Time      15.557406
# Block Address              8.498865
# Address Number             8.467843
# Zip Code                   1.006961
# Sector                     0.567583
# Beat                       0.567583
# City                       0.403607
# Street Type                0.107629
# Crime Name1                0.089902
# Crime Name2                0.089902
# Crime Name3                0.089902
# PRA                        0.077556
# Police District Name       0.029440
# Street Name                0.000317
# Start_Date_Time            0.000000
# Latitude                   0.000000
# Longitude                  0.000000
# Police District Number     0.000000
# Incident ID                0.000000
# Place                      0.000000
# Offence Code               0.000000
# Agency                     0.000000
# State                      0.000000
# ...

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;">3.3 Visualizing Missing data </h1>

# %% [markdown]
# Use !pip install missingno

# %%
import missingno as msno #Python library for the exploratory visualization of missing data.
msno.matrix(df)
plt.show()

# %% [markdown]
# More than 95% of the entries are null in Street Prefix’ and ‘Street Suffix’ columns
#
# About 50% of End Date Time's data is empty</li>
#
#
# A minimum of the following analysis must be present in this report:
# Initial Data Analysis:
# 1) Quality of data:
# a) Size of the dataset (Number of features and observations)
# b) Frequency counts (Missing values)
# c) Descriptive/Summary statistics (mean, median, standard deviation, etc.)
# d) Outliers detection
# e) Normality (frequency histograms)
#
# 2) Quality of measurements, if applicable
#
# 3) Data transformation: data merging (features and labels), transpose, data type change, data sorting, data deletion, etc.
#
# 4) Characteristics of dataset:
# a) Printing top and bottom 8 rows
# b) Basic plots
#
# Exploratory Data Analysis:
# 1. Finding null values and dealing with missing values with appropriate justification.
# 2. Correlation structures, distribution characteristics
# 3. Trends in data using appropriate visualization tools
# 4. Using appropriate plots, present the results of the research questions previously
# identified in the research report.
#  3
# 5. Correlation analysis
# Note: For visualization, use suitable

# %%
df.head()
# Out:
#    Incident ID Offence Code  CR Number    Dispatch Date / Time NIBRS Code  \
# 0    201219928         1204  180063894  12/21/2018 09:13:13 PM        120
# 1    201301798         5016  200035833  09/13/2020 12:26:58 AM        90Z
# 2    201221577         5404  190000342  01/03/2019 02:48:47 AM        90D
# 3    201221577         9053  190000342  01/03/2019 02:48:47 AM        90Z
# 4    201294935         2303  200027681  07/16/2020 05:29:50 PM        23C
#
#    Victims             Crime Name1                  Crime Name2  \
# 0        1  Crime Against Property                      Robbery
# 1        1   Crime Against Society           All Other Offenses
# 2        1   Crime Against Society  Driving Under the Influence
# 3        1                   Other           All Other Offenses
# 4        1  Crime Against Property                  Shoplifting
#
#                                   Crime Name3 Police District Name  ...  \
# ...

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;"> 3.4 Correlation Structures </h1>

# %%
data = df.copy()
data_copy = data.apply(lambda x: pd.factorize(x)[0]).corr(method = 'pearson', min_periods = 1)

# %%
plt.figure(figsize=(20,10))
corr_matrix = data_copy.corr()
sns.heatmap(corr_matrix, annot = True)
plt.show()

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:30px;"> 4.  Data Cleaning</h1>

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;"> 4.1  Finding duplicates </h1>

# %%
df[df.duplicated('Incident ID')] #Finding duplicate incident ids
# Out:
#         Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 3         201221577         9053  190000342  01/03/2019 02:48:47 AM
# 12        201141912         3542  170516482  06/29/2017 05:55:40 PM
# 24        201219904         1114  180059295  11/27/2018 03:01:27 PM
# 25        201219904         9003  180059295  11/27/2018 03:01:27 PM
# 33        201362228         4801  220003925  01/29/2022 03:25:31 PM
# ...             ...          ...        ...                     ...
# 315880    201390312         2305  220037642  08/31/2022 07:21:19 AM
# 315881    201390314         2305  220037646  08/31/2022 07:57:36 AM
# 315888    201390514         2303  220037902  09/01/2022 01:55:02 PM
# 315892    201395272         3560  220043017  10/02/2022 11:34:44 PM
# 315896    201395447         1399  220043955  10/08/2022 01:03:21 AM
#
#        NIBRS Code  Victims             Crime Name1  \
# 3             90Z        1                   Other
# ...

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;"> 4.2  Dropping unneccesary columns </h1>

# %%
#Dropping Street Prefix and Street Suffix since more than 90% if the data is missing and we already have sufficient 
#location details.
df.drop('Street Suffix', axis=1,inplace = True)
df.drop('Street Prefix', axis=1,inplace = True)

# %%
#Dropping other irrelevant columns for the desired analysis 
df.drop(columns=['Incident ID','CR Number','Location','Police District Number','Block Address',
                'Address Number','Zip Code'],inplace=True)

# %% [markdown]
# Justification for dropping
# <table>
#   <tr>
#     <th>Column Name</th>
#     <th>Justification for dropping</th>
#   </tr>
#   <tr>
#     <td>Incident ID, CR Number</td>
#     <td>Does not contribute anything relevant to the interpretation of the research questions.</td>
# </tr>
#   <tr>
#     <td>Location</td>
#     <td>Same set of co-ordinates are available in the latitude and longitude columns.</td>
#   </tr>
#    <tr>
#     <td>Police District Number</td>
#     <td>The corresponding Police District names are already available in the ‘Police District Name’ column.</td>
#   </tr>
#
# <tr>
#     <td>Block Address, Address Number, Zip Code</td>
#     <td>Does not contribute anything in addition as enough information describing the location is already available.
# </td>
#   </tr>

# %%
df.columns #out of 30 qualities, only 21 columns are chosen and the rest are dropped.
# Out:
# Index(['Offence Code', 'Dispatch Date / Time', 'NIBRS Code', 'Victims',
#        'Crime Name1', 'Crime Name2', 'Crime Name3', 'Police District Name',
#        'City', 'State', 'Agency', 'Place', 'Sector', 'Beat', 'PRA',
#        'Street Name', 'Street Type', 'Start_Date_Time', 'End_Date_Time',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;"> 4.3  Handling outliers </h1>

# %%
df[(df['Latitude']==0) & (df['Longitude']==0) ] #Finding Latitude and Longitude with 0 value
# Out:
#        Offence Code    Dispatch Date / Time NIBRS Code  Victims  \
# 30             1399  05/08/2022 08:48:39 PM        13B        1
# 55             2305  02/10/2022 08:53:04 AM        23F        1
# 56             2605  02/10/2022 08:53:04 AM        26B        1
# 68             9199  04/27/2020 05:42:43 PM        90Z        1
# 80             2404  12/20/2021 05:24:42 PM        240        1
# ...             ...                     ...        ...      ...
# 315861         9199  08/05/2022 08:36:38 AM        90Z        1
# 315863         1313  09/26/2022 07:00:52 PM        13B        1
# 315864         3532  09/25/2022 10:16:02 PM        35A        1
# 315866         9021  09/28/2022 05:25:11 PM        90I        1
# 315892         3560  10/02/2022 11:34:44 PM        35A        1
#
#                    Crime Name1                                 Crime Name2  \
# 30        Crime Against Person                              Simple Assault
# ...

# %% [markdown]
# #### 2.8% of the data in the Latitude and Longitude attributes are outliers. These rows are marked as outliers and will not be included while creating visualisations based on the location attribute.

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;"> 4.4  Converting Datatype</h1>

# %%
df['Dispatch Date / Time'] =  pd.to_datetime(df['Dispatch Date / Time']) #Changing the datatype of Dispatch date into date format

# %%
df['Start_Date_Time'] =  pd.to_datetime(df['Start_Date_Time'])#Changing the datatype of Start date into date format

# %%
df['End_Date_Time'] =  pd.to_datetime(df['End_Date_Time'])#Changing the datatype of End date into date format

# %%
df.info() #Checking whether the conversion is reflected
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315901 entries, 0 to 315900
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Offence Code          315901 non-null  object
#  1   Dispatch Date / Time  266755 non-null  datetime64[ns]
#  2   NIBRS Code            315901 non-null  object
#  3   Victims               315901 non-null  int64
#  4   Crime Name1           315617 non-null  object
#  5   Crime Name2           315617 non-null  object
#  6   Crime Name3           315617 non-null  object
#  7   Police District Name  315808 non-null  object
#  8   City                  314626 non-null  object
#  9   State                 315901 non-null  object
#  10  Agency                315901 non-null  object
#  11  Place                 315901 non-null  object
#  12  Sector                314108 non-null  object
#  13  Beat                  314108 non-null  object
# ...

# %%
df.head()
# Out:
#   Offence Code Dispatch Date / Time NIBRS Code  Victims  \
# 0         1204  2018-12-21 21:13:13        120        1
# 1         5016  2020-09-13 00:26:58        90Z        1
# 2         5404  2019-01-03 02:48:47        90D        1
# 3         9053  2019-01-03 02:48:47        90Z        1
# 4         2303  2020-07-16 17:29:50        23C        1
#
#               Crime Name1                  Crime Name2  \
# 0  Crime Against Property                      Robbery
# 1   Crime Against Society           All Other Offenses
# 2   Crime Against Society  Driving Under the Influence
# 3                   Other           All Other Offenses
# 4  Crime Against Property                  Shoplifting
#
#                                   Crime Name3 Police District Name  \
# 0                        ROBBERY - STREET-GUN              WHEATON
# 1  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN
# 2          DRIVING UNDER THE INFLUENCE LIQUOR            ROCKVILLE
# ...

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;"> 4.5  Fixing Errors </h1>

# %%
df[df['Start_Date_Time']>df['End_Date_Time']] # Finding all the rows where start time is greater than end time
# Out:
#        Offence Code Dispatch Date / Time NIBRS Code  Victims  \
# 1              5016  2020-09-13 00:26:58        90Z        1
# 44             2308  2020-11-12 16:26:36        23D        1
# 45             2610  2020-11-12 16:26:36        26F        1
# 92             2303  2020-02-01 13:54:38        23C        1
# 104            5309  2021-10-27 15:32:20        90Z        1
# ...             ...                  ...        ...      ...
# 315671         9101  2022-10-09 13:24:59        90Z        1
# 315763         2610  2022-08-17 22:24:25        26F        1
# 315842         9101  2022-09-21 16:50:18        90Z        1
# 315848         1316  2022-09-21 20:47:11        13C        1
# 315865         9107  2022-09-27 16:49:53        90Z        1
#
#                    Crime Name1          Crime Name2  \
# 1        Crime Against Society   All Other Offenses
# 44      Crime Against Property  Theft from Building
# 45      Crime Against Property       Identity Theft
# ...

# %%
df['End_Date_Time'] = np.where(df['Start_Date_Time']> df['End_Date_Time'], df['End_Date_Time'] + pd.Timedelta(days=1),df['End_Date_Time'])

# %%
df[df['Start_Date_Time']>df['End_Date_Time']]
# Out:
#        Offence Code Dispatch Date / Time NIBRS Code  Victims  \
# 22310          2316  2021-08-04 13:49:46        23H        1
# 64578          9107  2019-10-04 13:51:26        90Z        1
# 76184          9105                  NaT        90Z        1
# 77634          9101  2020-06-05 13:43:47        90Z        1
# 83167          9199  2021-02-05 20:33:45        90Z        1
# 141879         2605  2017-05-01 11:41:17        26B        1
# 162060         1316  2017-12-03 15:53:41        13C        1
# 193486         1199  2018-01-19 13:48:26        11D        1
# 195665         9110  2018-01-19 13:48:26        90Z        1
# 200434         2203  2018-10-25 15:13:41        220        1
#
#                    Crime Name1                                 Crime Name2  \
# 22310   Crime Against Property                           All other Larceny
# 64578                    Other                          All Other Offenses
# ...

# %%
df.drop(df[df['Start_Date_Time']>df['End_Date_Time']].index, inplace=True)

# %%
df[df['Start_Date_Time']>df['End_Date_Time']]
# Out:
# Empty DataFrame
# Columns: [Offence Code, Dispatch Date / Time, NIBRS Code, Victims, Crime Name1, Crime Name2, Crime Name3, Police District Name, City, State, Agency, Place, Sector, Beat, PRA, Street Name, Street Type, Start_Date_Time, End_Date_Time, Latitude, Longitude]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;"> 4.6  Handling Inconsistent Records </h1>

# %% [markdown]
# ##### The dataset entries are inconsistent and has capital letters in some columns and small in others. Hence, apart from the columns with abbreviations, all the entries are changed to correct case to ensure uniformity.

# %%
cols = ['Crime Name1', 'Crime Name2', 'Crime Name3',
       'Police District Name', 'City', 'State', 
       'Agency', 'Beat', 'PRA',
       'Street Name']
df[cols] = df[cols].apply(lambda x: x.str.capitalize()) #Using the string function to capitalize only the first letter of each entry.

# %%
df.head() #Checking the results
# Out:
#   Offence Code Dispatch Date / Time NIBRS Code  Victims  \
# 0         1204  2018-12-21 21:13:13        120        1
# 1         5016  2020-09-13 00:26:58        90Z        1
# 2         5404  2019-01-03 02:48:47        90D        1
# 3         9053  2019-01-03 02:48:47        90Z        1
# 4         2303  2020-07-16 17:29:50        23C        1
#
#               Crime Name1                  Crime Name2  \
# 0  Crime against property                      Robbery
# 1   Crime against society           All other offenses
# 2   Crime against society  Driving under the influence
# 3                   Other           All other offenses
# 4  Crime against property                  Shoplifting
#
#                                   Crime Name3 Police District Name  \
# 0                        Robbery - street-gun              Wheaton
# 1  Obstruct govt - violation of a court order           Germantown
# 2          Driving under the influence liquor            Rockville
# ...

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:30px;"> 5.  Data Transformation</h1>

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;"> 5.1  Creating a new attribute </h1>

# %%
df['Duration'] = df['End_Date_Time']-df['Start_Date_Time']

# %%
df[df.Duration == df.Duration.max()]
# Out:
#       Offence Code Dispatch Date / Time NIBRS Code  Victims Crime Name1  \
# 38689         9105                  NaT        90Z        1       Other
#
#               Crime Name2    Crime Name3 Police District Name           City  \
# 38689  All other offenses  Lost property              Wheaton  Silver spring
#
#       State  ... Sector Beat  PRA Street Name Street Type     Start_Date_Time  \
# 38689    Md  ...      L  4l1  366    Randolph          RD 2016-07-11 16:45:00
#
#       End_Date_Time  Latitude Longitude           Duration
# 38689    2022-07-08  39.05842  -77.0484 2187 days 07:15:00
#
# [1 rows x 22 columns]

# %%
df['Response time'] = df['Dispatch Date / Time']-df['Start_Date_Time']

# %%
df[df['Response time'] == df['Response time'].max()]
# Out:
#        Offence Code Dispatch Date / Time NIBRS Code  Victims  \
# 310190         2610  2022-09-20 12:44:30        26F        1
#
#                    Crime Name1     Crime Name2     Crime Name3  \
# 310190  Crime against property  Identity theft  Identity theft
#
#        Police District Name          City State  ... Beat  PRA Street Name  \
# 310190   Montgomery village  Gaithersburg    Md  ...  6p2  593    Sullnick
#
#        Street Type Start_Date_Time End_Date_Time  Latitude Longitude Duration  \
# 310190         WAY      2016-08-15           NaT  39.14825  -77.2354      NaT
#
#             Response time
# 310190 2227 days 12:44:30
#
# [1 rows x 23 columns]

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;"> 5.2  Extracting Month and Year </h1>

# %%
#Creating new columns for month and year for time-based visualizations
df['Month'] = df['Start_Date_Time'].dt.month #Extracting only the month from the date and storing it in a new column 'month'
df['Year'] = df['Start_Date_Time'].dt.year #Extracting only the year from the date and storing it in a new column 'month'

df['Month_Year'] = pd.to_datetime(df['Start_Date_Time']).dt.strftime('%m-%Y')

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;"> 5.4  Discretization and Binning </h1>

# %% [markdown]
# #### The crime severity level/ Harm Level is cateogirised into Individual Level, Community Level or Societal Level based on the no of victims affected.

# %%
df['Victims'].value_counts() # Checking the range of victims to create bins.
# Out:
# 1     310088
# 2       4906
# 3        594
# 4        202
# 5         60
# 6         18
# 7         16
# 8          4
# 12         2
# 22         1
# Name: Victims, dtype: int64

# %%
df['Harm Level'] = pd.cut(df['Victims'], [0,4,8,22], labels=['Individual Level', 'Community Level', 'Societal Level'])
#Labels are given to the customised bins, 0-4:Individual Level; 5-8:Community Level; >8:Community Level;

# %%
df[df['Harm Level']=='Individual Level'] #Displaying individual level crimes
# Out:
#        Offence Code Dispatch Date / Time NIBRS Code  Victims  \
# 0              1204  2018-12-21 21:13:13        120        1
# 1              5016  2020-09-13 00:26:58        90Z        1
# 2              5404  2019-01-03 02:48:47        90D        1
# 3              9053  2019-01-03 02:48:47        90Z        1
# 4              2303  2020-07-16 17:29:50        23C        1
# ...             ...                  ...        ...      ...
# 315896         1399  2022-10-08 01:03:21        13B        1
# 315897         2303  2022-10-07 14:16:41        23C        1
# 315898         2303  2022-10-07 12:04:02        23C        1
# 315899         1399  2022-10-08 09:03:17        13B        1
# 315900         2303  2022-10-08 11:07:28        23C        1
#
#                    Crime Name1                  Crime Name2  \
# 0       Crime against property                      Robbery
# 1        Crime against society           All other offenses
# ...

# %%
df[df['Harm Level']=='Community Level'] #Displaying community level crimes
# Out:
#        Offence Code Dispatch Date / Time NIBRS Code  Victims  \
# 41             6411  2017-12-20 08:42:35        64A        7
# 1963           1313  2021-09-19 21:17:11        13B        5
# 9569           1315  2021-10-13 15:45:08        13A        6
# 12501          1304  2021-06-11 01:57:28        13A        5
# 14572          1399  2021-06-19 17:28:19        13B        5
# ...             ...                  ...        ...      ...
# 304469         1399  2022-09-16 17:56:13        13B        6
# 305754         1399  2022-07-05 00:37:33        13B        5
# 309188         1315  2022-09-18 18:46:49        13A        5
# 315439         1314  2022-09-29 11:58:59        13A        5
# 315447         9199  2022-09-30 12:08:25        90Z        5
#
#                  Crime Name1                             Crime Name2  \
# 41      Crime against person  Human trafficking, commercial sex acts
# 1963    Crime against person                          Simple assault
# ...

# %%
df[df['Harm Level']=='Societal Level'] #Displaying societal level crimes
# Out:
#        Offence Code Dispatch Date / Time NIBRS Code  Victims  \
# 39840          9109  2017-04-16 19:13:44        90Z       12
# 101975         9199  2022-03-02 21:34:35        90Z       12
# 106641         1313                  NaT        13B       22
#
#                  Crime Name1         Crime Name2                 Crime Name3  \
# 39840                  Other  All other offenses  Recovered property - other
# 101975                 Other  All other offenses          Police information
# 106641  Crime against person      Simple assault            Assault - simple
#
#        Police District Name           City State  ...     Start_Date_Time  \
# 39840              Bethesda       Bethesda    Md  ... 2017-04-16 19:13:00
# 101975            Rockville      Rockville    Md  ... 2022-03-02 21:00:00
# 106641        Silver spring  Silver spring    Md  ... 2016-07-23 16:30:00
#
#              End_Date_Time   Latitude  Longitude        Duration  \
# ...

# %%
df.groupby(df['Harm Level']).count().sort_values(ascending=False, by = 'Offence Code')
# Out:
#                   Offence Code  Dispatch Date / Time  NIBRS Code  Victims  \
# Harm Level
# Individual Level        315790                266660      315790   315790
# Community Level             98                    84          98       98
# Societal Level               3                     2           3        3
#
#                   Crime Name1  Crime Name2  Crime Name3  Police District Name  \
# Harm Level
# Individual Level       315507       315507       315507                315697
# Community Level            97           97           97                    98
# Societal Level              3            3            3                     3
#
#                     City   State  ...  Street Type  Start_Date_Time  \
# Harm Level                        ...
# Individual Level  314515  315790  ...       315450           315790
# Community Level       98      98  ...           98               98
# Societal Level         3       3  ...            3                3
#
# ...

# %%
df.columns
# Out:
# Index(['Offence Code', 'Dispatch Date / Time', 'NIBRS Code', 'Victims',
#        'Crime Name1', 'Crime Name2', 'Crime Name3', 'Police District Name',
#        'City', 'State', 'Agency', 'Place', 'Sector', 'Beat', 'PRA',
#        'Street Name', 'Street Type', 'Start_Date_Time', 'End_Date_Time',
#        'Latitude', 'Longitude', 'Duration', 'Response time', 'Month', 'Year',
#        'Month_Year', 'Harm Level'],
#       dtype='object')

# %%
df['Harm Level'].value_counts()*100/df.shape[0]
# Out:
# Individual Level    99.968027
# Community Level      0.031023
# Societal Level       0.000950
# Name: Harm Level, dtype: float64

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;"> Basic numbers based on the type of Crime </h1>

# %%
crime_type = df['Crime Name1'].value_counts().rename_axis('CN1').reset_index(name = 'counts')
c_type_labels = crime_type.CN1
c_type_values = crime_type.counts

# %%
plt.figure(figsize=(20,10))
plt.style.use('ggplot')
plt.bar(crime_type.CN1, crime_type.counts)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.pie(crime_type.counts, labels = c_type_labels, autopct='%.0f%%')
plt.show()

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud

plt.rcParams['figure.figsize'] = (15, 15)
plt.style.use('ggplot')

wc = WordCloud(background_color = 'orange', width = 1500, height = 1500).generate(str(df['Crime Name3']))
plt.title('Word Cloud for Montgomery County Crimes', fontsize = 20)

plt.imshow(wc)
plt.axis('off')
plt.show()

# %% [markdown]
# # Research Questions

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;">1. What kind of behaviour have the crime rates shown throughout the years? How do crimes stack up against one another when looking back over the previous five years? </h1>

# %%
year = df['Year'].value_counts()
year
# Out:
# 2017    56291
# 2018    54336
# 2019    51464
# 2020    44934
# 2021    43726
# 2022    36895
# 2016    28245
# Name: Year, dtype: int64

# %%
year_trend = df['Year'].value_counts().rename_axis('Year').reset_index(name = 'counts')
year_labels = year_trend.Year
year_values = year_trend.counts

# %%
plt.figure(figsize=(20,10))
plt.bar(year_trend.Year, year_trend.counts)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.pie(year_trend.counts, labels = year_labels, autopct='%.0f%%')
plt.show()

# %%
df.index = pd.DatetimeIndex(df.Month_Year)
plt.figure(figsize=(20,10))
df.resample('M').size().plot(legend=False)
plt.title('Trend of crimes (2017 - 2022)')
plt.xlabel('Years')
plt.ylabel('Number of crimes')
plt.show()

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;"> 2. What is the average response time of the police department? Response time is the period between when a crime is perpetrated or reported and when police are dispatched.</h1>

# %% [markdown]
# To determine the response time, we must first determine how much time has passed between the time of dispatch and the beginning of the activity. It was decided to remove 15% of rows to ensure that only relevant data is retained since more than 15% of the data was missing from dispatch date time. However, we opted to keep the rows intact. Not only does the average response time exceed 8 days, but the minimum value is -1369 days, and the maximum value is 2227 days, suggesting that the data provided in the dispatch date time is being improperly passed through. The median time was little over 5 minutes, which makes a lot of sense realistically when gauging a police organisation 's effectiveness.

# %%
df['Response time'].median()
# Out:
# Timedelta('0 days 00:05:11')

# %%
df["Response time"].groupby(df["Agency"]).median().sort_values(ascending=False).dropna()
# Out:
# Agency
# P      0 days 09:26:00.500000
# Rcpd          0 days 00:01:12
# Mcpd          0 days 00:00:51
# Tppd          0 days 00:00:43
# Gpd           0 days 00:00:32
# Mcfm          0 days 00:00:16
# Mcso        -1 days +23:59:33
# Name: Response time, dtype: timedelta64[ns]

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;"> 3. How long does criminal behaviour typically last? What region has the longest typical crime episode? How often do extended periods of increased crime occur? In what ways does average period change amongst police agencies?</h1>

# %%
df["Duration"].groupby(df["Place"]).median().sort_values(ascending=False).dropna()
# Out:
# Place
# Residence - Carport                            0 days 13:30:00
# Construction Site                              0 days 13:02:00
# Parking Garage - Residential                   0 days 12:30:00
# Residence - Driveway                           0 days 11:00:00
# Parking Lot - Park & Ride                      0 days 10:20:00
# Residence - Shed                               0 days 09:37:00
# Parking Lot - Residential                      0 days 09:30:00
# Residence - Garage                             0 days 02:30:00
# Rental Storage Facility                        0 days 02:00:00
# Golf Course                                    0 days 01:30:00
# Street - Residential                           0 days 01:07:30
# Auto Repair                                    0 days 01:07:00
# Residence - Other                              0 days 01:04:30
# Amusement Park                                 0 days 00:55:00
# Parking Lot - Church                           0 days 00:49:00
# ...

# %%
agency = df['Agency'].value_counts().rename_axis('Agency').reset_index(name = 'counts')
agency_labels = agency.Agency
agency_values = agency.counts

# %%
plt.figure(figsize=(20,10))
plt.pie(agency_values, labels = agency_labels, autopct='%.2f%%')
plt.show()

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;"> 4. Which area is the most and least dangerous? How has crime performed in these areas over the past five years? What sorts of crimes are often committed in the safest and most hazardous areas? How often do criminal acts occur in these regions? </h1>

# %%
area = df['Victims'].groupby(df['Police District Name']).count().sort_values(ascending=False)
area
# Out:
# Police District Name
# Silver spring          66450
# Wheaton                59367
# Montgomery village     54282
# Bethesda               44276
# Rockville              42819
# Germantown             40403
# City of takoma park     6408
# Takoma park             1540
# Other                    253
# Name: Victims, dtype: int64

# %%
area_pct = df['Police District Name'].value_counts()*100/df.shape[0]
area_pct
# Out:
# Silver spring          21.035737
# Wheaton                18.793508
# Montgomery village     17.183775
# Bethesda               14.016227
# Rockville              13.554992
# Germantown             12.790171
# City of takoma park     2.028548
# Takoma park             0.487510
# Other                   0.080091
# Name: Police District Name, dtype: float64

# %%
area_year = df.groupby(['Year', 'Police District Name']).count().sort_values(ascending=False, by = 'Victims')
area_year.head(62)
# Out:
#                            Offence Code  Dispatch Date / Time  NIBRS Code  \
# Year Police District Name
# 2017 Silver spring                12039                  9048       12039
# 2018 Silver spring                11506                 11262       11506
# 2019 Silver spring                11351                 10279       11351
# 2017 Wheaton                      11113                  8238       11113
# 2018 Wheaton                      10792                 10701       10792
# ...                                 ...                   ...         ...
#      Other                            4                     4           4
# 2020 Takoma park                      2                     2           2
# 2017 Other                            1                     1           1
# 2016 Takoma park                      1                     0           1
# 2019 Takoma park                      1                     1           1
#
# ...

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;"> 5. What sort of location (e.g., streets, residences, grocery stores, etc.) has the highest and the lowest crime rate? What kind of crimes are being perpetrated in these regions? Which location is the constantly looking least hazardous to dwell in or reside near? </h1>

# %%
location = df['Victims'].groupby(df['Place']).count().sort_values(ascending=False)
location[location > 20000] #Using >20000 to ensure only the ones with maximum crime rate are displayed
# Out:
# Place
# Street - In vehicle            34202
# Residence - Single Family      33453
# Residence - Apartment/Condo    30198
# Other/Unknown                  26376
# Street - Residential           20826
# Name: Victims, dtype: int64

# %%
location[location <= 5] #Using <5 to ensure only the ones with minimum crime rate are displayed
# Out:
# Place
# Amusement Park                       4
# Industrial Site                      4
# Camp / Campground                    2
# Rest Area                            2
# Dock/Wharf/Freight/Modal Terminal    2
# Name: Victims, dtype: int64

# %%
place = df['Place'].value_counts().rename_axis('Place').reset_index(name = 'counts')
plt.figure(figsize=(20,10))

plt.bar(place.Place, place.counts)
plt.xticks(rotation = 90)
plt.show()

# %%
df.groupby(['Crime Name1', 'Place']).count().sort_values(ascending=False, by = 'Year') 

# Grouping data by Crime Name and Place to find which location 
# is constantly looking most hazardous to dwell in or reside near
# Out:
#                                                           Offence Code  \
# Crime Name1            Place
# Crime against society  Street - In vehicle                       28611
# Crime against property Other/Unknown                             16759
# Other                  Residence - Single Family                 13799
# Crime against property Parking Lot - Residential                 13052
#                        Street - Residential                      13040
# ...                                                                ...
# Crime against person   Farm Facility                                 1
#                        Nursery                                       1
# Other                  Pedestrian Tunnel                             1
# Crime against property Dock/Wharf/Freight/Modal Terminal             1
# Not a crime            Retail - Appliances/Electronics               1
#
#                                                           Dispatch Date / Time  \
# ...

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;"> 6. What kinds of streets are among the most susceptible to crime, and what kinds of crimes occur on the most hazardous streets? What are the most and least desirable times to commute on the street? What kind of crimes are committed along these streets?</h1>

# %%
street = df['Victims'].groupby(df['Street Type']).count().sort_values(ascending=False)

# %%
street
# Out:
# Street Type
# RD     78573
# AVE    67835
# DR     53032
# ST     19594
# BLV    16808
# LA     16784
# CT     14392
# WAY     9076
# TER     8333
# PIK     7893
# PL      7846
# CIR     7603
# HWY     4333
# PKW     2779
# SQ       141
# RMP      117
# PLZ      109
# CTR      103
# MEW       40
# RUN       27
# CRE       26
# TRL       26
# AL        20
# OV        18
# LP        12
# DRW        9
# ENT        7
# ESP        5
# RVR        4
# COV        4
# FAR        1
# END        1
# Name: Victims, dtype: int64

# %%
street_crime = df['Street Type'].value_counts().rename_axis('ST').reset_index(name = 'counts')
plt.figure(figsize=(20,10))

plt.bar(street_crime.ST, street_crime.counts)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 9)
plt.style.use('seaborn')

color = plt.cm.spring(np.linspace(0, 1, 15))
df['Street Name'].value_counts().head(30).plot.bar(color = color, figsize = (15, 10))

plt.title('Most unsafe streets',fontsize = 30)

plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;"> 7. What is the least desirable time to go out alone in the whole county? Additionally, when is the safest time to leave the house? How many potential victims are stuck at a crime scene on average during these times? </h1>

# %%
df['Time'] = df['Start_Date_Time'].dt.strftime('%H:%M:%S %p')

# %%
night_to_noon = df[df['Time'] < '12:00:00 PM']
noon_to_night = df[df['Time'] >= '12:00:00 PM']

# %%
night_to_noon['Crime Name1'].count()*100/df.shape[0]
# Out:
# 34.82530366487175

# %%
noon_to_night['Crime Name1'].count()*100/df.shape[0]
# Out:
# 65.08479190606887

# %%
df[df['Time'] > '12:00:00 PM'].groupby('Police District Name').count().sort_values(ascending=False, by = "Crime Name1")
# Out:
#                       Offence Code  Dispatch Date / Time  NIBRS Code  Victims  \
# Police District Name
# Silver spring                42785                 36329       42785    42785
# Wheaton                      37665                 31894       37665    37665
# Montgomery village           33670                 28505       33670    33670
# Bethesda                     27239                 23473       27239    27239
# Germantown                   26093                 22284       26093    26093
# Rockville                    25034                 21332       25034    25034
# City of takoma park           3866                  3282        3866     3866
# Takoma park                    881                   874         881      881
# Other                          149                   142         149      149
#
#                       Crime Name1  Crime Name2  Crime Name3   City  State  \
# Police District Name
# ...

# %%
df[df['Time'] < '12:00:00 PM'].groupby('Police District Name').count().sort_values(ascending=False, by = "Crime Name1")
# Out:
#                       Offence Code  Dispatch Date / Time  NIBRS Code  Victims  \
# Police District Name
# Silver spring                22267                 18367       22267    22267
# Wheaton                      20375                 16880       20375    20375
# Montgomery village           19167                 16097       19167    19167
# Rockville                    16261                 13042       16261    16261
# Bethesda                     15480                 13157       15480    15480
# Germantown                   13425                 11273       13425    13425
# City of takoma park           2358                  1979        2358     2358
# Takoma park                    641                   636         641      641
# Other                           99                    86          99       99
#
#                       Crime Name1  Crime Name2  Crime Name3   City  State  \
# Police District Name
# ...

# %% [markdown]
# <h1 style="background-color:#b3e6ff; color:#3d0066;font-size:15px;"> 8. When comparing crime figures from 2019 to 2020, what insights come into picture? How significant was COVID-19 in causing countywide crime trends to shift? Which part of the country had the biggest growth in safety, and which saw the most decline in security, over this phase? </h1>

# %%
pre_covid = df[df['Year'] < 2020].count()
pre_covid[0]*100/df.shape[0]
# Out:
# 60.25369510369083

# %%
post_covid = df[df['Year'] >= 2020].count()
post_covid[0]*100/df.shape[0]
# Out:
# 39.74630489630917
